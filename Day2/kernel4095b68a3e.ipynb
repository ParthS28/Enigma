# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
#pd.set_option('display.max_rows', None)
from sklearn.linear_model import SGDClassifier,SGDRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm

# import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/enigma-day2/sample_submission.csv
# /kaggle/input/enigma-day2/test.csv
# /kaggle/input/enigma-day2/train.csv

# %%
train = pd.read_csv('/kaggle/input/enigma-day2/train.csv')
test = pd.read_csv('/kaggle/input/enigma-day2/test.csv')

# %%
id = test['Id']

# %%
train['area'] = train['Length(m)'] * train['Width(m)']
test['area'] = test['Length(m)'] * test['Width(m)']

train['food/month'] = train['Food Availible(Kg)'] / train['Months']
test['food/month'] = test['Food Availible(Kg)'] / test['Months']
# train = train.drop(['Length(m)', 'Width(m)'], axis = 1)
# test = test.drop(['Length(m)', 'Width(m)'], axis = 1)

train = train.drop(['Length(m)', 'Width(m)', 'Months', 'Food Availible(Kg)'], axis = 1)
test = test.drop(['Length(m)', 'Width(m)', 'Months', 'Food Availible(Kg)'], axis = 1)
train
# Out:
#           People  Population  Survival %   Id     area  food/month
# 0          Slavs       242.0     11.5200    0   762.00    5.771144
# 1          Slavs       340.0     12.3778    2   824.15    5.089329
# 2          Slavs       430.0     12.4440    4   986.00    5.161667
# 3          Slavs       450.0     13.6024    5  1030.59    5.438974
# 4          Slavs       500.0     14.1795    6  1024.65    5.077200
# ..           ...         ...         ...  ...      ...         ...
# 107  Handicapped         9.9      2.2139  152   154.58    9.692083
# 108  Handicapped         9.8      2.2044  153   158.40    9.926855
# 109  Handicapped        13.4      2.4300  155   167.40    9.219858
# 110  Handicapped        12.2      2.2770  156   179.40    9.635292
# 111  Handicapped        19.7      2.8728  157   217.36    6.385449
#
# [112 rows x 6 columns]

# %%
types = ['POWs', 'Handicapped', 'Parkki', 'Undesirables', 'Poles', 'Slavs', 'Jews']

slavs_train = train[train['People'] == 'Slavs']
slavs_test = test[test['People'] == 'Slavs']

poles_train = train[train['People'] == 'Poles']
poles_test = test[test['People'] == 'Poles']

pows_train = train[train['People'] == 'POWs']
pows_test = test[test['People'] == 'POWs']

parki_train = train[train['People'] == 'Parkki']
parki_test = test[test['People'] == 'Parkki']


jews_train = train[train['People'] == 'Jews']
jews_test = test[test['People'] == 'Jews']

un_train = train[train['People'] == 'Undesirables']
un_test = test[test['People'] == 'Undesirables']

hands_train = train[train['People'] == 'Handicapped']
hands_test = test[test['People'] == 'Handicapped']

# %%
slavs_train_x = slavs_train.drop(['Id', 'Survival %', 'People'], axis = 1)
slavs_train_y = slavs_train['Survival %']
slavs_test_x = slavs_test.drop(['Id', 'People'], axis = 1)

poles_train_x = poles_train.drop(['Id', 'Survival %', 'People'], axis = 1)
poles_train_y = poles_train['Survival %']
poles_test_x = poles_test.drop(['Id', 'People'], axis = 1)

pows_train_x = pows_train.drop(['Id', 'Survival %', 'People'], axis = 1)
pows_train_y = pows_train['Survival %']
pows_test_x = pows_test.drop(['Id', 'People'], axis = 1)

parki_train_x = parki_train.drop(['Id', 'Survival %', 'People'], axis = 1)
parki_train_y = parki_train['Survival %']
parki_test_x = parki_test.drop(['Id', 'People'], axis = 1)

jews_train_x = jews_train.drop(['Id', 'Survival %', 'People'], axis = 1)
jews_train_y = jews_train['Survival %']
jews_test_x = jews_test.drop(['Id', 'People'], axis = 1)

un_train_x = un_train.drop(['Id', 'Survival %', 'People'], axis = 1)
un_train_y = un_train['Survival %']
un_test_x = un_test.drop(['Id', 'People'], axis = 1)

hands_train_x = hands_train.drop(['Id', 'Survival %', 'People'], axis = 1)
hands_train_y = hands_train['Survival %']
hands_test_x = hands_test.drop(['Id', 'People'], axis = 1)

# %%
rf = RandomForestRegressor()

rf.fit(slavs_train_x, slavs_train_y)
slavs_pred = rf.predict(slavs_test_x)

# %%
rf = RandomForestRegressor()

rf.fit(poles_train_x, poles_train_y)
poles_pred = rf.predict(poles_test_x)

# %%
rf = RandomForestRegressor()

rf.fit(pows_train_x, pows_train_y)
pows_pred = rf.predict(pows_test_x)

# %%
rf = RandomForestRegressor()

rf.fit(parki_train_x, parki_train_y)
parki_pred = rf.predict(parki_test_x)

# %%
rf = RandomForestRegressor()

rf.fit(jews_train_x, jews_train_y)
jews_pred = rf.predict(jews_test_x)

# %%
rf = RandomForestRegressor()

rf.fit(un_train_x, un_train_y)
un_pred = rf.predict(un_test_x)

# %%
rf = RandomForestRegressor()

rf.fit(hands_train_x, hands_train_y)
hands_pred = rf.predict(hands_test_x)

# %%
preds = []
for pred in slavs_pred:
    preds.append(pred)
for pred in poles_pred:
    preds.append(pred)
for pred in pows_pred:
    preds.append(pred)
for pred in parki_pred:
    preds.append(pred)
for pred in jews_pred:
    preds.append(pred)
for pred in un_pred:
    preds.append(pred)
for pred in hands_pred:
    preds.append(pred)

# %%
len(preds)
# Out:
# 47

# %%
preds
# Out:
# [12.169974999999988,
#  12.662147999999993,
#  13.648575999999997,
#  14.092354999999987,
#  14.683253999999998,
#  15.639660000000008,
#  15.721178000000009,
#  15.421226999999998,
#  16.128087000000008,
#  17.913008,
#  6.264110999999997,
#  6.367029999999999,
#  6.638155000000004,
#  6.988848999999998,
#  11.253806000000013,
#  7.563449999999996,
#  9.698439999999998,
#  5.278521000000003,
#  5.416599000000008,
#  5.742350999999997,
#  6.060428000000004,
#  6.022071000000004,
#  6.004203000000002,
#  6.0790239999999995,
#  6.3611119999999985,
#  6.6528239999999945,
#  7.174383999999999,
#  7.235503999999995,
#  9.442900999999996,
#  10.667482000000001,
#  11.68846199999999,
#  10.876639000000003,
#  12.045507999999998,
#  12.084558999999999,
#  12.005781999999995,
#  6.3666480000000005,
#  6.490446000000002,
#  7.148970000000002,
#  7.5124379999999915,
#  8.095581999999993,
#  9.548466000000005,
#  1.9077100000000002,
#  2.108789000000003,
#  2.1237500000000025,
# ...

# %%
df = pd.DataFrame({'Id': id, 'Survival %': preds})

# %%
df.to_csv('submission.csv', index = False)
